# %%
from path import Path
import pandas as pd
data = Path('legend_key.xlsx')
key_df = pd.read_excel(data)
key_df.head()
# Out:
#    sex_code     sex  chest_pain_code   chest_pain_type  \
# 0       0.0  female                0    typical angina
# 1       1.0    male                1   atypical angina
# 2       NaN     NaN                2  non-anginal pain
# 3       NaN     NaN                3      asymptomatic
#
#    fasting_blood_sugar_code fasting_blood_sugar  resting_ecg_results_code  \
# 0                       0.0        under 120 mg                       0.0
# 1                       1.0         over 120 mg                       1.0
# 2                       NaN                 NaN                       2.0
# 3                       NaN                 NaN                       NaN
#
#             resting_ecg_results  exercise_induced_angincode  \
# 0                        normal                         0.0
# 1         ST-T wave abnormality                         1.0
# 2  left ventricular hypertrophy                         NaN
# 3                           NaN                         NaN
#
# ...

# %%
from sqlalchemy import create_engine
from config import db_password

# %%
db_string = f"postgresql://postgres:{db_password}@database-1.cnpkdgamerbc.us-east-1.rds.amazonaws.com:5432/heart_data_base"

# %%
engine = create_engine(db_string)

# %%
key_df.to_sql(name='legend_key', con=engine)
